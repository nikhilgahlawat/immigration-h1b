# %% [markdown]
# # Labor Condition Applications (LCAs)
# ## Clean up fields

# %%
# Import packages
import pandas as pd
import re

# %%
# Set up parameters
data_dir = '../../data/'
input_dir = data_dir + 'intermediate/'
input_filename = 'lca_deduped.csv'
output_dir = data_dir + 'intermediate/'
output_filename = 'lca_fields.csv'

# %%
# Load data
lca = pd.read_csv(input_dir + input_filename, dtype=str)

# %% [markdown]
# ### Standardize yes/no columns

# %%
def print_value_counts(cols):
  for col in cols:
    print(lca[col].value_counts(dropna=False).sort_index())
    print('')

# %%
def standardize_yes_no(value):
  if not isinstance(value, str):
    val = value
  elif value.lower().strip() in ['y', 'yes']:
    val = 'Y'
  elif value.lower().strip() in ['n', 'no']:
    val = 'N'
  else:
    val = value
  return val

# %%
yes_no_cols = ['FULL_TIME_POSITION', 'H_1B_DEPENDENT', 'WILLFUL_VIOLATOR']

# %%
print_value_counts(yes_no_cols)
# Out:
# FULL_TIME_POSITION
# N       123786
# Y      5539865
# NaN     799965
# Name: count, dtype: int64
#
# H_1B_DEPENDENT
# N      1931288
# No     1062941
# Y      1261146
# Yes     436157
# NaN    1772084
# Name: count, dtype: int64
#
# WILLFUL_VIOLATOR
# N      3190032
# No     1498642
# Y         2383
# Yes        451
# NaN    1772108
# Name: count, dtype: int64

# %%
for col in yes_no_cols:
  lca[col] = lca[col].apply(standardize_yes_no)

# %%
print_value_counts(yes_no_cols)
# Out:
# FULL_TIME_POSITION
# N       123786
# Y      5539865
# NaN     799965
# Name: count, dtype: int64
#
# H_1B_DEPENDENT
# N      2994229
# Y      1697303
# NaN    1772084
# Name: count, dtype: int64
#
# WILLFUL_VIOLATOR
# N      4688674
# Y         2834
# NaN    1772108
# Name: count, dtype: int64

# %% [markdown]
# ### Standardize statutory basis

# %%
lca['STATUTORY_BASIS'].value_counts(dropna=False)
# Out:
# STATUTORY_BASIS
# NaN                                                                                        5845889
# $60,000 or higher annual wage                                                               321608
# WAGE                                                                                        134021
# Both $60,000 or higher in annual wage and Masters Degree or higher in related specialty     111103
# BOTH                                                                                         48856
# Masters Degree or higher in related specialty                                                 1212
# DEGREE                                                                                         927
# Name: count, dtype: int64

# %%
def standardize_statutory_basis(value):
  if pd.isnull(value):
    val = pd.NA
  elif value == '$60,000 or higher annual wage':
    val = 'WAGE'
  elif value == 'Masters Degree or higher in related specialty':
    val = 'DEGREE'
  elif value == 'Both $60,000 or higher in annual wage and Masters Degree or higher in related specialty':
    val = 'BOTH'
  else:
    val = value
  return val

# %%
lca['STATUTORY_BASIS'] = lca['STATUTORY_BASIS'].apply(standardize_statutory_basis)

# %%
lca['STATUTORY_BASIS'].value_counts(dropna=False)
# Out:
# STATUTORY_BASIS
# <NA>      5845889
# WAGE       455629
# BOTH       159959
# DEGREE       2139
# Name: count, dtype: int64

# %%
def standardize_pw_level(value):
  if pd.isnull(value):
    val = pd.NA
  elif value.lower().strip() in ['i', 'level i']:
    val = 'Level I'
  elif value.lower().strip() in ['ii', 'level ii']:
    val = 'Level II'
  elif value.lower().strip() in ['iii', 'level iii']:
    val = 'Level III'
  elif value.lower().strip() in ['iv', 'level iv']:
    val = 'Level IV'
  else:
    val = pd.NA
  return val

# %%
lca['PW_WAGE_LEVEL'] = lca['PW_WAGE_LEVEL'].apply(standardize_pw_level)

# %%
lca['PW_WAGE_LEVEL'].value_counts(dropna=False)
# Out:
# PW_WAGE_LEVEL
# <NA>         2502904
# Level II     1840872
# Level I       863027
# Level III     760697
# Level IV      496116
# Name: count, dtype: int64

# %% [markdown]
# ### Wage fields

# %% [markdown]
# #### Standardize prevailing wage level

# %%
lca['PW_WAGE_LEVEL'].value_counts(dropna=False)
# Out:
# PW_WAGE_LEVEL
# <NA>         2502904
# Level II     1840872
# Level I       863027
# Level III     760697
# Level IV      496116
# Name: count, dtype: int64

# %% [markdown]
# There are a handful of records that specify a prevailing wage level of "V", which doesn't exist. There are only 4 wage levels.
# Set these instances to null.

# %% [markdown]
# #### Create an annualized prevailing wage field
# Prevailing wages and wage ranges can be reported at different rates (yearly, hourly, etc).  Create a new field for the annualized pay rate so cases can be compared.

# %%
# Set the prevailing wage field to type float
lca['PREVAILING_WAGE'] = lca['PREVAILING_WAGE'].astype(float)

# %%
lca['PW_UNIT_OF_PAY'].value_counts(dropna=False)
# Out:
# PW_UNIT_OF_PAY
# Year         6013133
# Hour          437992
# Month           5087
# NaN             4803
# Week            1880
# Bi-Weekly        721
# Name: count, dtype: int64

# %%
def annualize_wages(row, wage_col):
  unit = row['PW_UNIT_OF_PAY']
  pw = row[wage_col]

  if pd.isna(unit) or pd.isna(pw):
    return pd.NA

  unit = unit.lower().strip()

  if unit == 'year':
    pw_stz = pw
  elif unit == 'month':
    pw_stz = pw * 12
  elif unit == 'bi-weekly':
    pw_stz = pw * 26
  elif unit == 'week':
    pw_stz = pw * 52
  elif unit == 'hour':
    pw_stz = pw * 40 * 52
  else:
    pw_stz = pd.NA
  
  return round(pw_stz)

# %%
lca['PW_ANNUAL'] = lca.apply(lambda row: annualize_wages(row, 'PREVAILING_WAGE'), axis=1)

# %% [markdown]
# Check a handful of each wage rate to see if the converstion was successful

# %%
lca[['PW_UNIT_OF_PAY', 'PREVAILING_WAGE', 'PW_ANNUAL']].sort_values('PW_UNIT_OF_PAY').groupby('PW_UNIT_OF_PAY', dropna=False).head(3)
# Out:
#         PW_UNIT_OF_PAY  PREVAILING_WAGE PW_ANNUAL
# 6394985      Bi-Weekly          3807.20     98987
# 2718570      Bi-Weekly          1635.20     42515
# 2419020      Bi-Weekly          3597.00     93522
# 5693262           Hour            31.49     65499
# 3089483           Hour            21.80     45344
# 321123            Hour            24.46     50877
# 5555643          Month          4544.79     54537
# 1465860          Month          3657.00     43884
# 1105076          Month         10439.84    125278
# 17796             Week           768.47     39960
# 5002997           Week          1573.60     81827
# 313765            Week          1542.00     80184
# 4394777           Year         63918.00     63918
# 4377290           Year         71906.00     71906
# 4362151           Year        179462.00    179462
# 3529674            NaN             0.00      <NA>
# 3811348            NaN              NaN      <NA>
# 3811349            NaN              NaN      <NA>

# %% [markdown]
# #### Clean up wage range fields

# %% [markdown]
# Manually inspecting the "FROM" field shows that there are a few main types of entries:
#  - A single number, either as a whole number or decimal: "60000" or "45.60"
#  - A range: "102500 - 122900" or "95594.00 - 99639.87"
#  - A range missing an upper bound: "95000 -" or "135000.00 -"
#
# The "TO" field seems to have only single numbers, no ranges.
#
# We'll create two new fields for the lower and upper wage values.
#
# For the lower bound:
#  - Split the WAGE_RATE_OF_PAY_FROM field on "-"
#  - Set the wage lower bound field using the first value of the split
#  - Save the second value of the split to fill in the the upper bound field
#
# For the upper bound:
#  - If WAGE_RATE_OF_PAY_TO is not missing, set the upper bound field to this value
#  - If WAGE_RATE_OF_PAY_TO is missing, set the upper bound to the second value of WAGE_RATE_OF_PAY_FROM, if it exists.

# %% [markdown]
# First, clean up the "FROM" field by removing any characters that are not a number, period, or dash.

# %%
def remove_non_numeric_chars(s):
  if not isinstance(s, str):
    return s
  return re.sub(r'[^0-9\.-]', '', s)

# %%
lca['WAGE_RATE_OF_PAY_FROM'] = lca['WAGE_RATE_OF_PAY_FROM'].apply(remove_non_numeric_chars)

# %% [markdown]
# Split the "FROM" wage field

# %%
wage_ranges = lca['WAGE_RATE_OF_PAY_FROM'].str.split('-', expand=True)
wage_ranges.columns = ['WAGE_SPLIT_1', 'WAGE_SPLIT_2']

# %%
lca = lca.join(wage_ranges)

# %% [markdown]
# Set the new wage columns

# %%
lca['WAGE_FROM'] = lca['WAGE_SPLIT_1'].replace({pd.NA: None, '': None}).astype(float)

# %%
lca['WAGE_TO'] = lca['WAGE_RATE_OF_PAY_TO'].combine_first(lca['WAGE_SPLIT_2']).replace({pd.NA: None, '': None}).astype(float)

# %% [markdown]
# Inspect the new columns

# %%
lca.loc[:, ['WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO', 'WAGE_SPLIT_1', 'WAGE_SPLIT_2', 'WAGE_FROM', 'WAGE_TO']]
# Out:
#         WAGE_RATE_OF_PAY_FROM WAGE_RATE_OF_PAY_TO WAGE_SPLIT_1 WAGE_SPLIT_2  \
# 0                       82300              125000        82300         None
# 1                       57000                 NaN        57000         None
# 2                       34695                 NaN        34695         None
# 3                       44408                 NaN        44408         None
# 4                       63180                 NaN        63180         None
# ...                       ...                 ...          ...          ...
# 6463611              350000.0            450000.0     350000.0         None
# 6463612               92050.0                 NaN      92050.0         None
# 6463613              125000.0                 NaN     125000.0         None
# 6463614               92650.0                 NaN      92650.0         None
# 6463615              164674.0            170356.7     164674.0         None
#
#          WAGE_FROM   WAGE_TO
# 0          82300.0  125000.0
# 1          57000.0       NaN
# 2          34695.0       NaN
# 3          44408.0       NaN
# 4          63180.0       NaN
# ...            ...       ...
# 6463611   350000.0  450000.0
# 6463612    92050.0       NaN
# 6463613   125000.0       NaN
# 6463614    92650.0       NaN
# 6463615   164674.0  170356.7
#
# [6463616 rows x 6 columns]

# %%
# Check instances when the original "TO" field is not null
# The new WAGE_UPPER field should equal the old WAGE_RATE_OF_PAY_TO field
lca.loc[(~lca['WAGE_RATE_OF_PAY_TO'].isna()) & (lca['WAGE_SPLIT_2'].isna()), ['WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO', 'WAGE_SPLIT_1', 'WAGE_SPLIT_2', 'WAGE_FROM', 'WAGE_TO']]
# Out:
#         WAGE_RATE_OF_PAY_FROM WAGE_RATE_OF_PAY_TO WAGE_SPLIT_1 WAGE_SPLIT_2  \
# 0                       82300              125000        82300         None
# 5                      110000              110000       110000         None
# 15                      60950               80000        60950         None
# 21                      62000               90000        62000         None
# 34                      55000               65000        55000         None
# ...                       ...                 ...          ...          ...
# 6463607              126173.0            132088.0     126173.0         None
# 6463609                  40.0                41.0         40.0         None
# 6463610               98904.0            100000.0      98904.0         None
# 6463611              350000.0            450000.0     350000.0         None
# 6463615              164674.0            170356.7     164674.0         None
#
#          WAGE_FROM   WAGE_TO
# 0          82300.0  125000.0
# 5         110000.0  110000.0
# 15         60950.0   80000.0
# 21         62000.0   90000.0
# 34         55000.0   65000.0
# ...            ...       ...
# 6463607   126173.0  132088.0
# 6463609       40.0      41.0
# 6463610    98904.0  100000.0
# 6463611   350000.0  450000.0
# 6463615   164674.0  170356.7
#
# [2940753 rows x 6 columns]

# %%
# Check instances when the original WAGE_RATE_OF_PAY_TO field is null but the second element of the wage split is not
# The new wage field should equal the second elemnt of the wage split field
lca.loc[(lca['WAGE_RATE_OF_PAY_TO'].isna()) & (~lca['WAGE_SPLIT_2'].isna()), ['WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO', 'WAGE_SPLIT_1', 'WAGE_SPLIT_2', 'WAGE_FROM', 'WAGE_TO']]
# Out:
#         WAGE_RATE_OF_PAY_FROM WAGE_RATE_OF_PAY_TO WAGE_SPLIT_1 WAGE_SPLIT_2  \
# 1668528             85000.00-                 NaN     85000.00
# 1668529           66000-70000                 NaN        66000        70000
# 1668530          97000-143300                 NaN        97000       143300
# 1668531            155000.00-                 NaN    155000.00
# 1668532          64100-127000                 NaN        64100       127000
# ...                       ...                 ...          ...          ...
# 6187093                60000-                 NaN        60000
# 6187094                70000-                 NaN        70000
# 6187095             69000.00-                 NaN     69000.00
# 6187096             60000.00-                 NaN     60000.00
# 6187097                70000-                 NaN        70000
#
#          WAGE_FROM   WAGE_TO
# 1668528    85000.0       NaN
# 1668529    66000.0   70000.0
# 1668530    97000.0  143300.0
# 1668531   155000.0       NaN
# 1668532    64100.0  127000.0
# ...            ...       ...
# 6187093    60000.0       NaN
# 6187094    70000.0       NaN
# 6187095    69000.0       NaN
# 6187096    60000.0       NaN
# 6187097    70000.0       NaN
#
# [517718 rows x 6 columns]

# %%
# Check instances where both are null
# The new wage field should also be null
lca.loc[(lca['WAGE_RATE_OF_PAY_TO'].isna()) & (lca['WAGE_SPLIT_2'].isna()), ['WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO', 'WAGE_SPLIT_1', 'WAGE_SPLIT_2', 'WAGE_FROM', 'WAGE_TO']]
# Out:
#         WAGE_RATE_OF_PAY_FROM WAGE_RATE_OF_PAY_TO WAGE_SPLIT_1 WAGE_SPLIT_2  \
# 1                       57000                 NaN        57000         None
# 2                       34695                 NaN        34695         None
# 3                       44408                 NaN        44408         None
# 4                       63180                 NaN        63180         None
# 6                       42204                 NaN        42204         None
# ...                       ...                 ...          ...          ...
# 6463605              117500.0                 NaN     117500.0         None
# 6463608              345000.0                 NaN     345000.0         None
# 6463612               92050.0                 NaN      92050.0         None
# 6463613              125000.0                 NaN     125000.0         None
# 6463614               92650.0                 NaN      92650.0         None
#
#          WAGE_FROM  WAGE_TO
# 1          57000.0      NaN
# 2          34695.0      NaN
# 3          44408.0      NaN
# 4          63180.0      NaN
# 6          42204.0      NaN
# ...            ...      ...
# 6463605   117500.0      NaN
# 6463608   345000.0      NaN
# 6463612    92050.0      NaN
# 6463613   125000.0      NaN
# 6463614    92650.0      NaN
#
# [3005145 rows x 6 columns]

# %% [markdown]
# Annualize the new wage fields

# %%
lca['WAGE_ANNUAL_FROM'] = lca.apply(lambda row: annualize_wages(row, 'WAGE_FROM'), axis=1)
lca['WAGE_ANNUAL_TO'] = lca.apply(lambda row: annualize_wages(row, 'WAGE_TO'), axis=1)

# %% [markdown]
# Check a handful of each wage rate to see if the converstion was successful

# %%
lca[['PW_UNIT_OF_PAY', 'WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO', 'WAGE_ANNUAL_FROM', 'WAGE_ANNUAL_TO']].sort_values('PW_UNIT_OF_PAY').groupby('PW_UNIT_OF_PAY', dropna=False).head(3)
# Out:
#         PW_UNIT_OF_PAY WAGE_RATE_OF_PAY_FROM WAGE_RATE_OF_PAY_TO  \
# 6394985      Bi-Weekly               4230.78                 NaN
# 2718570      Bi-Weekly                1635.2                   0
# 2419020      Bi-Weekly                  3597                4526
# 5693262           Hour                 34.61                 NaN
# 3089483           Hour                  21.8                   0
# 321123            Hour                 24.46                  28
# 5555643          Month                5499.0              5500.0
# 1465860          Month                  3750                 NaN
# 1105076          Month              10439.84            12041.67
# 17796             Week                   800                 NaN
# 5002997           Week                1573.6                 NaN
# 313765            Week                  1542                1808
# 4394777           Year                 82000               82000
# 4377290           Year                104800              157200
# 4362151           Year                280000              325000
# 3529674            NaN                     0                   0
# 3811348            NaN                    33                 NaN
# 3811349            NaN                136178                 NaN
#
#         WAGE_ANNUAL_FROM WAGE_ANNUAL_TO
# 6394985           110000           <NA>
# 2718570            42515              0
# 2419020            93522         117676
# 5693262            71989           <NA>
# 3089483            45344              0
# 321123             50877          58240
# 5555643            65988          66000
# 1465860            45000           <NA>
# 1105076           125278         144500
# 17796              41600           <NA>
# 5002997            81827           <NA>
# 313765             80184          94016
# 4394777            82000          82000
# 4377290           104800         157200
# 4362151           280000         325000
# 3529674             <NA>           <NA>
# 3811348             <NA>           <NA>
# 3811349             <NA>           <NA>

# %% [markdown]
# #### Fix cases with unusually high wages
# There are some cases where the annualized wages are unusually high. To investigate this issue we created a wage ratio metric, calculated as the ratio between the the intended wage and the prevailing wage. Diving into cases with the highest wage ratios, it looks like there are a few different things going on:
#  - In many cases the prevailing wage is provided at an hourly rate but the intended wage appears to be an annual rate. A spike in the wage ratio distribution around 2080 - which is the multiplier used to convert hourly wages to annual (52*40) - appears to support this idea.
#  - In some cases there appears to be a missing decimal point in the intended wage. For instance, the prevailing wage is listed as 60,000 but the intended wage is 6,000,000 or 600,000. A missing decimal point seems more likely than an employer paying 100x the prevailing wage.
#  - In one case (`I-200-12080-308552`) there seems to be a missing dash. The intended wage is "4500055000" but should likely be "45000-55000", which would be comparable to the prevailing wage for the occupation.
#  - In other cases, it's not entirely clear why the intended wage is orders of magnitude higher than the prevailing wage.
#
# Overall, there are relatively few of these cases. Of a total of 6.5M cases, ~5k cases have a wage ratio greater than 10. Most of these (~3k) seem to stem from listing an hourly prevailing wage and an annual intended wage. We'll attempt to correct these cases.
#
# It's more difficult to determine the root cause of the remaining cases so we'll leave them be for now. Any wage analysis will have to keep this potential data issue in mind (e.g. report on percentiles or medians instead of averages).
#
# Here's what we'll do to fix the hourly/annual issue:
#  1. Flag cases that list an hourly prevailing wage and have a wage ratio greater than 2000.
#  2. Set the annualized wages to the intended wage provided on the LCA. In other words, we'll revert the wage annualization for these cases.

# %%
# Subset of columns to use when investigating this issue
wage_cols = ['EMPLOYER_NAME', 'JOB_TITLE', 'SOC_CODE', 'SOC_TITLE', 'PW_UNIT_OF_PAY', 'PREVAILING_WAGE', 'PW_ANNUAL', 'WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO', 'WAGE_SPLIT_1', 'WAGE_SPLIT_2', 'WAGE_ANNUAL_FROM', 'WAGE_ANNUAL_TO', 'WAGE_RATIO']

# %%
# Calculate the ratio of the given wage to the prevailing wage
# In theory these should be comparable. High ratios signal that something strange is going on.
lca['WAGE_RATIO'] = lca['WAGE_SPLIT_1'].astype(float) / lca['PREVAILING_WAGE'].astype(float)

# %%
wage_ratio_threshold = 2000
wage_fix_filter = (lca['PW_UNIT_OF_PAY'] == 'Hour') & (lca['WAGE_RATIO'] > wage_ratio_threshold)

# %%
print('A wage ratio threshold of ' + str(wage_ratio_threshold) + ' will update ' + str(lca.loc[wage_fix_filter].shape[0]) + ' records.')
# Out:
# A wage ratio threshold of 2000 will update 3156 records.

# %%
# Apply the wage fix
lca.loc[wage_fix_filter, ['WAGE_ANNUAL_FROM', 'WAGE_ANNUAL_TO']] = lca.loc[wage_fix_filter, ['WAGE_SPLIT_1', 'WAGE_SPLIT_2']].values

# %% [markdown]
# ## Save file

# %%
# Save analysis file
lca.to_csv(output_dir + output_filename, index=False)

# %% [markdown]
# ### SOC codes and titles
# _IN PROGRESS_

# %%
# Load columns for cleaning up SOC codes and titles
soc_cols = ['CASE_NUMBER', 'DATAFILE_YEAR', 'DATAFILE_QUARTER', 'EMPLOYER_NAME', 'SOC_CODE', 'SOC_TITLE']

# %%
# Load file
lca = pd.read_csv(output_dir + output_filename, usecols=soc_cols, index_col='CASE_NUMBER')

# %%
lca.dtypes
# Out:
# EMPLOYER_NAME        object
# SOC_CODE             object
# SOC_TITLE            object
# DATAFILE_YEAR         int64
# DATAFILE_QUARTER    float64
# dtype: object

# %%
lca.head(50)
# Out:
#                                                         EMPLOYER_NAME  \
# CASE_NUMBER
# I-200-20259-823768                 \t1. UBS BUSINESS SOLUTIONS US LLC
# I-200-22238-441074                \tAimbridge Employee Service Corp.
# I-200-21295-662005            \tAlliance for Sustainable Energy, LLC
# I-200-21305-680234                        \tArtemis Consulting, Inc.
# I-200-22010-819571                        \tAsclepius Solutions Inc.
# I-200-23087-884020                                    \tAttainX, Inc.
# I-200-19343-187664                             \tAuto TechLabs, Inc.
# I-200-20058-356819                             \tAuto TechLabs, Inc.
# I-200-20084-432378                             \tAuto TechLabs, Inc.
# I-200-20238-786589                             \tAuto TechLabs, Inc.
# I-200-21133-311310                        \tBetter Nutritionals, LLC
# I-200-22118-115245                     \tBranch, Richards & Co., P.S.
# I-200-21291-651013                   \tBrown Brothers Harriman & Co.
# I-200-21342-753261                   \tBrown Brothers Harriman & Co.
# I-200-22013-827756                   \tBrown Brothers Harriman & Co.
# I-200-22063-952805                   \tBrown Brothers Harriman & Co.
# I-200-22083-008059                   \tBrown Brothers Harriman & Co.
# I-200-22104-072886                   \tBrown Brothers Harriman & Co.
# I-200-22117-111291                   \tBrown Brothers Harriman & Co.
# I-200-22126-145219                   \tBrown Brothers Harriman & Co.
# I-200-22164-272608                   \tBrown Brothers Harriman & Co.
# I-200-22166-281950                   \tBrown Brothers Harriman & Co.
# I-200-22168-292156                   \tBrown Brothers Harriman & Co.
# I-200-22182-328825                   \tBrown Brothers Harriman & Co.
# I-200-22186-332760                   \tBrown Brothers Harriman & Co.
# I-200-22243-448341                   \tBrown Brothers Harriman & Co.
# I-200-22255-467393                   \tBrown Brothers Harriman & Co.
# I-200-22264-484921                   \tBrown Brothers Harriman & Co.
# I-200-22264-484936                   \tBrown Brothers Harriman & Co.
# I-200-23080-864626                   \tBrown Brothers Harriman & Co.
# I-200-23067-831573                   \tBrown Brothers Harriman & Co.
# I-200-23058-805678                   \tBrown Brothers Harriman & Co.
# I-200-23115-964432                   \tBrown Brothers Harriman & Co.
# I-200-22270-496364                   \tBrown Brothers Harriman & Co.
# I-200-22271-499040                   \tBrown Brothers Harriman & Co.
# I-200-22320-590010                   \tBrown Brothers Harriman & Co.
# I-200-21244-559307         \tCanadian Solar (USA) Energy Corporation
# I-203-23034-748263                              \tDelivery Associates
# I-200-22277-510366                \tEDP Renewables North America LLC
# I-200-23096-908915  \tEmbraer Engineering & Technology Center USA,...
# I-200-23220-248307  \tEmbraer Engineering & Technology Center USA,...
# I-200-22274-505573                \tEmbraer Executive Aircraft, Inc.
# I-200-19310-129947                                   \tEon Labs, Inc.
# I-200-22229-420855                         \tEvolectric Incorporated
# I-200-20335-930216                          \tFortress Resources, LLC
# I-200-22019-839270                            \tFuture Textiles, Inc
# I-200-23094-901588               \tGlobe Trailer Manufacturing, Inc.
# I-200-23103-932092                       \tICON TECHNICAL GROUP, INC.
# I-200-21301-674173                               \tInflammatix, Inc.
# I-200-20111-499779               \tInstrumentation Laboratory Company
#
#                       SOC_CODE  \
# CASE_NUMBER
# I-200-20259-823768  15-1133.00
# I-200-22238-441074  11-3131.00
# I-200-21295-662005  19-2041.00
# I-200-21305-680234  13-1161.00
# I-200-22010-819571  15-1132.00
# I-200-23087-884020  15-2099.01
# I-200-19343-187664  15-1141.00
# I-200-20058-356819  15-1132.00
# I-200-20084-432378  15-1132.00
# I-200-20238-786589  15-1132.00
# I-200-21133-311310  19-1012.00
# I-200-22118-115245  13-2011.00
# I-200-21291-651013  15-1132.00
# I-200-21342-753261  15-1132.00
# I-200-22013-827756  15-1132.00
# I-200-22063-952805  15-1133.00
# I-200-22083-008059  15-1132.00
# I-200-22104-072886  15-1132.00
# I-200-22117-111291  15-1199.01
# I-200-22126-145219  13-2051.00
# I-200-22164-272608  15-1132.00
# I-200-22166-281950  15-1199.01
# I-200-22168-292156  15-1132.00
# I-200-22182-328825  15-1252.00
# I-200-22186-332760  15-1211.00
# I-200-22243-448341  15-1252.00
# I-200-22255-467393  15-1252.00
# I-200-22264-484921  15-1211.00
# I-200-22264-484936  15-1252.00
# I-200-23080-864626  15-1252.00
# I-200-23067-831573  15-1299.08
# I-200-23058-805678  15-1252.00
# I-200-23115-964432  15-1252.00
# I-200-22270-496364  15-1253.00
# I-200-22271-499040  15-1252.00
# I-200-22320-590010  15-1252.00
# I-200-21244-559307  13-2011.01
# I-203-23034-748263  13-1111.00
# I-200-22277-510366  13-1081.02
# I-200-23096-908915  17-2112.00
# I-200-23220-248307  17-2112.03
# I-200-22274-505573  17-2011.00
# I-200-19310-129947  11-9111.00
# I-200-22229-420855  17-2141.00
# I-200-20335-930216  17-2141.00
# I-200-22019-839270  13-1081.02
# I-200-23094-901588  17-2141.00
# I-200-23103-932092  15-1252.00
# I-200-21301-674173  15-1133.00
# I-200-20111-499779  13-1161.00
#
#                                                             SOC_TITLE  \
# CASE_NUMBER
# I-200-20259-823768              Software Developers, Systems Software
# I-200-22238-441074                  Training and Development Managers
# I-200-21295-662005  Environmental Scientists and Specialists, Incl...
# I-200-21305-680234  Market Research Analysts and Marketing Special...
# I-200-22010-819571                  Software Developers, Applications
# I-200-23087-884020                         Bioinformatics Technicians
# I-200-19343-187664                            Database Administrators
# I-200-20058-356819                  Software Developers, Applications
# I-200-20084-432378                  Software Developers, Applications
# I-200-20238-786589                  Software Developers, Applications
# I-200-21133-311310                  Food Scientists and Technologists
# I-200-22118-115245                           Accountants and Auditors
# I-200-21291-651013                  Software Developers, Applications
# I-200-21342-753261                  Software Developers, Applications
# I-200-22013-827756                  Software Developers, Applications
# I-200-22063-952805              Software Developers, Systems Software
# I-200-22083-008059                  Software Developers, Applications
# I-200-22104-072886                  Software Developers, Applications
# I-200-22117-111291   Software Quality Assurance Engineers and Testers
# I-200-22126-145219                                 Financial Analysts
# I-200-22164-272608                  Software Developers, Applications
# I-200-22166-281950   Software Quality Assurance Engineers and Testers
# I-200-22168-292156                  Software Developers, Applications
# I-200-22182-328825                                Software Developers
# I-200-22186-332760                          Computer Systems Analysts
# I-200-22243-448341                                Software Developers
# I-200-22255-467393                                Software Developers
# I-200-22264-484921                          Computer Systems Analysts
# I-200-22264-484936                                Software Developers
# I-200-23080-864626                                Software Developers
# I-200-23067-831573              Computer Systems Engineers/Architects
# I-200-23058-805678                                Software Developers
# I-200-23115-964432                                Software Developers
# I-200-22270-496364    Software Quality Assurance Analysts and Testers
# I-200-22271-499040                                Software Developers
# I-200-22320-590010                                Software Developers
# I-200-21244-559307                                        Accountants
# I-203-23034-748263                                Management Analysts
# I-200-22277-510366                                 Logistics Analysts
# I-200-23096-908915                               Industrial Engineers
# I-200-23220-248307                            Manufacturing Engineers
# I-200-22274-505573                                Aerospace Engineers
# I-200-19310-129947               Medical and Health Services Managers
# I-200-22229-420855                               Mechanical Engineers
# I-200-20335-930216                               MECHANICAL ENGINEERS
# I-200-22019-839270                                 Logistics Analysts
# I-200-23094-901588                               Mechanical Engineers
# I-200-23103-932092                                Software Developers
# I-200-21301-674173              Software Developers, Systems Software
# I-200-20111-499779  Market Research Analysts and Marketing Special...
#
#                     DATAFILE_YEAR  DATAFILE_QUARTER
# CASE_NUMBER
# I-200-20259-823768           2020               4.0
# I-200-22238-441074           2022               4.0
# I-200-21295-662005           2022               1.0
# I-200-21305-680234           2022               1.0
# I-200-22010-819571           2022               2.0
# I-200-23087-884020           2023               3.0
# I-200-19343-187664           2020               1.0
# I-200-20058-356819           2020               2.0
# I-200-20084-432378           2020               2.0
# I-200-20238-786589           2020               4.0
# I-200-21133-311310           2021               3.0
# I-200-22118-115245           2022               3.0
# I-200-21291-651013           2022               1.0
# I-200-21342-753261           2022               1.0
# I-200-22013-827756           2022               2.0
# I-200-22063-952805           2022               2.0
# I-200-22083-008059           2022               2.0
# I-200-22104-072886           2022               3.0
# I-200-22117-111291           2022               3.0
# I-200-22126-145219           2022               3.0
# I-200-22164-272608           2022               3.0
# I-200-22166-281950           2022               3.0
# I-200-22168-292156           2022               3.0
# I-200-22182-328825           2022               4.0
# I-200-22186-332760           2022               4.0
# I-200-22243-448341           2022               4.0
# I-200-22255-467393           2022               4.0
# I-200-22264-484921           2022               4.0
# I-200-22264-484936           2022               4.0
# I-200-23080-864626           2023               2.0
# I-200-23067-831573           2023               2.0
# I-200-23058-805678           2023               2.0
# I-200-23115-964432           2023               3.0
# I-200-22270-496364           2023               2.0
# I-200-22271-499040           2023               2.0
# I-200-22320-590010           2023               2.0
# I-200-21244-559307           2021               4.0
# I-203-23034-748263           2023               2.0
# I-200-22277-510366           2023               2.0
# I-200-23096-908915           2023               3.0
# I-200-23220-248307           2023               4.0
# I-200-22274-505573           2023               2.0
# I-200-19310-129947           2020               1.0
# I-200-22229-420855           2022               4.0
# I-200-20335-930216           2021               3.0
# I-200-22019-839270           2022               2.0
# I-200-23094-901588           2023               3.0
# I-200-23103-932092           2023               3.0
# I-200-21301-674173           2022               1.0
# I-200-20111-499779           2020               3.0

# %%
lca['SOC_CODE'].value_counts(dropna=False)
# Out:
# SOC_CODE
# 15-1132                      658914
# 15-1132.00                   474036
# 15-1121                      440080
# Computer Systems Analysts    287370
# 15-1199                      267292
#                               ...
# Carpet Installers                 1
# Camera Operators                  1
# 39-1011                           1
# 35-3021                           1
# 47-2181.00                        1
# Name: count, Length: 2719, dtype: int64

# %%
lca['SOC_TITLE'].value_counts(dropna=False)
# Out:
# SOC_TITLE
# SOFTWARE DEVELOPERS, APPLICATIONS    653452
# Software Developers, Applications    480214
# COMPUTER SYSTEMS ANALYSTS            352868
# COMPUTER OCCUPATIONS, ALL OTHER      247898
# COMPUTER PROGRAMMERS                 241332
#                                       ...
# SENIOR DEVELOPER-BIOINFORMATICS           1
# POST-DOCTORATE CHEMIST                    1
# CRM SIEBEL ARCHITECT                      1
# ANDROID PROGRAMMER                        1
# EMBEDDED LINUX SOFTWARE ENGINEER          1
# Name: count, Length: 206735, dtype: int64

# %%
lca[['SOC_CODE', 'SOC_TITLE']].value_counts(dropna=False)
# Out:
# SOC_CODE                          SOC_TITLE
# 15-1132                           SOFTWARE DEVELOPERS, APPLICATIONS       652563
# 15-1132.00                        Software Developers, Applications       473608
# 15-1121                           COMPUTER SYSTEMS ANALYSTS               348753
# 15-1199                           COMPUTER OCCUPATIONS, ALL OTHER         247819
# 15-1131                           COMPUTER PROGRAMMERS                    237225
#                                                                            ...
# Electrical Engineers              DIRECTOR OF ENGINEERING SERVICES             1
#                                   DIRECTOR OF HARDWARE ENGINEERING             1
#                                   DIRECTOR OF PRODUCT DEVELOPMENT              1
#                                   DIRECTOR OF PRODUCT ENGINEERING              1
# Financial Specialists, All Other  ASSOCIATE, RISK & PORTFOLIO ANALYSIS         1
# Name: count, Length: 291202, dtype: int64

# %%
lca[['DATAFILE_YEAR', 'SOC_CODE', 'SOC_TITLE']].value_counts(dropna=False)
# Out:
# DATAFILE_YEAR  SOC_CODE              SOC_TITLE
# 2019           15-1132               SOFTWARE DEVELOPERS, APPLICATIONS            193987
# 2020           15-1132.00            Software Developers, Applications            170826
# 2023           15-1252.00            Software Developers                          170457
# 2018           15-1132               SOFTWARE DEVELOPERS, APPLICATIONS            169491
# 2021           15-1132.00            Software Developers, Applications            151504
#                                                                                    ...
# 2012           Animal Scientists     LATIN AMERICA EMBRYO TRANSFER COORDINATOR         1
#                                      LABORATORY RESEARCH MANAGER                       1
#                                      HORSE CONSULTANT (ANIMAL SCIENTIST)               1
#                                      HERD HEALTH MANAGER/ANIMAL SCIENTIST              1
#                Mechanical Engineers  SENIOR AERODYNAMICS DESIGN ENGINEER               1
# Name: count, Length: 393997, dtype: int64
